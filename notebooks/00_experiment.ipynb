# %%
import requests
import datetime
import time
import os, sys
import pandas as pd
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), "."))
from config.filters import SPESE, INCOME, RIMBORSI, INVESTIMENTI, BUONI_PASTO
from dotenv import load_dotenv
load_dotenv()
WALLET_API_TOKEN = os.getenv("WALLET_API_TOKEN")

# %%
def call_wallet_api(endpoint: str, args: dict = None, base_url = "https://rest.budgetbakers.com/wallet"):
    headers = {"Authorization": f"Bearer {WALLET_API_TOKEN}"}
    request_url = f"{base_url}/{endpoint}"
    # send the request with a payload of params
    response = requests.get(request_url, headers=headers, params=args)
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception(f"API call failed with status code {response.status_code}: {response.text}")

accounts = call_wallet_api("v1/api/accounts")
accounts = {account['name']: account['id'] for account in accounts['accounts']}

# %%
accounts
# Out:
# {'Prepaid XME plus': '1a5c2400-70b0-421f-8bc4-39f95bf879f1',
#  'Trade Republic': '24df231a-1cc3-4bcb-8528-242c4889bc1c',
#  'Buoni pasto': '2b044f45-7a57-4095-bbad-9cd2f49a7fa0',
#  'Fineco': '355bbb52-ecb7-4717-b170-9eeb2cd0b063',
#  'Intesa San Paolo': '3b544b6c-9653-4968-ac71-daa82252b738',
#  'Banco BPM': '67ea39ef-ac84-48ac-9c48-ff8f9049a1c1',
#  'Scalable Capital': '6e418d8c-ab2b-4977-abc1-f1ce7a864506',
#  'Cash': '7296cfee-ff1a-497f-8382-fcc7a265e23a',
#  'PayPal': '8cd5ee39-e099-47e7-90e1-03585a866e7b',
#  'Revolut': '8ff2d76e-f475-4af6-b265-f677b2c1996a',
#  'Satispay': 'cf067959-f56a-4cb0-bd6d-ace82640d3b4'}

# %%
first_day_of_this_month = datetime.date.today().replace(day=1)
first_day_of_last_month = (first_day_of_this_month - datetime.timedelta(days=1)).replace(day=1).isoformat()
last_date_of_last_month = (first_day_of_this_month - datetime.timedelta(days=1)).isoformat()
# first_day_of_last_month = (datetime.date.today() - datetime.timedelta(days=1)).isoformat()
# last_date_of_last_month = (datetime.date.today()).isoformat()
# first_day_of_last_month = "2025-01-01"
# last_date_of_last_month = "2025-12-31"
print(f"Fetching records from {first_day_of_last_month} to {last_date_of_last_month}")

records_df = pd.DataFrame()

i = 0

for account_name, account_id in accounts.items():
    while True:    
        n_records_retrieved = i * 100

        args = {
                "accountId": account_id,
                "recordDate": f"lte.{last_date_of_last_month}",
                "limit": 100,
                "offset": n_records_retrieved
            }
        time.sleep(1)
        print(f"Fetching records for account {account_name} with offset {n_records_retrieved}")
        records = call_wallet_api("v1/api/records", args=args)

        if len(records['records']) > 0:
            account_records = records['records']
            for record in account_records:
                cat_id = record['category']['id']
                cat_name = record['category']['name']
                date = record['recordDate']
                amount = record['amount']["value"]
                label_ids = [label['id'] for label in record.get('labels', [])]
                label_names = [label['name'] for label in record.get('labels', [])]

                new_row = {
                    "account": account_name,
                    "amount": amount,
                    "date": date,
                    "category_id": cat_id,
                    "category_name": cat_name,
                    "label_ids": label_ids,
                    "label_names": label_names
                }
                records_df = pd.concat([records_df, pd.DataFrame([new_row])], ignore_index=True)
                
            i += 1
        else:
            i = 0
            break

records_df = records_df[records_df['date'] >= first_day_of_last_month]
# Out:
# Fetching records from 2026-01-01 to 2026-01-31
# Fetching records for account Prepaid XME plus with offset 0
# Fetching records for account Trade Republic with offset 0
# Fetching records for account Trade Republic with offset 100
# Fetching records for account Trade Republic with offset 200
# Fetching records for account Trade Republic with offset 300
# Fetching records for account Buoni pasto with offset 0
# Fetching records for account Fineco with offset 0
# Fetching records for account Intesa San Paolo with offset 0
# Fetching records for account Intesa San Paolo with offset 100
# Fetching records for account Banco BPM with offset 0
# Fetching records for account Banco BPM with offset 100
# Fetching records for account Scalable Capital with offset 0
# Fetching records for account Scalable Capital with offset 100
# Fetching records for account Cash with offset 0
# Fetching records for account Cash with offset 100
# Fetching records for account PayPal with offset 0
# Fetching records for account PayPal with offset 100
# Fetching records for account Revolut with offset 0
# Fetching records for account Revolut with offset 100
# Fetching records for account Satispay with offset 0
# Fetching records for account Satispay with offset 100

# %%
records_df
# Out:
#             account  amount                  date  \
# 158  Trade Republic  -26.80  2026-01-01T06:21:11Z
# 159  Trade Republic    4.26  2026-01-01T09:32:59Z
# 160  Trade Republic  -19.89  2026-01-01T12:00:00Z
# 161  Trade Republic  -90.00  2026-01-01T16:01:00Z
# 162  Trade Republic   -9.95  2026-01-01T18:00:38Z
# ..              ...     ...                   ...
# 468         Revolut   13.16  2026-01-31T10:05:42Z
# 469        Satispay    5.00  2026-01-13T09:52:16Z
# 470        Satispay    4.80  2026-01-13T13:19:09Z
# 471        Satispay   -7.60  2026-01-13T16:53:21Z
# 472        Satispay   -3.00  2026-01-13T17:51:28Z
#
#                               category_id            category_name  \
# 158  7c7dfaee-3be0-474e-b337-bd8b4e735940                   Eventi
# 159  7af26741-a212-47da-a50c-baeb717e9db4                Interessi
# 160  68b6ced6-1c86-4534-8c88-704e0de6519e
# 161  fe2cd110-9275-4f28-92f0-ecb3bfb1663e   Ristoranti & Fast-food
# 162  d69edfb5-81ef-42b5-8908-49db1a17e9a6                   Regali
# ..                                    ...                      ...
# 468  c196e895-83d8-4118-b744-94321501287e                 Rimborsi
# 469  c196e895-83d8-4118-b744-94321501287e                 Rimborsi
# 470  b6a83884-8a6b-4071-a660-e1a36bc28cde  Trasferimento, Prelievo
# 471  a0e0eaa6-9f83-43fd-afd7-59e20d0381ae                 Shopping
# 472  9defe17c-1cd4-4460-8ece-96fd90a76690             Bar & Locali
#
#                                   label_ids label_names
# 158  [8921b28b-b4ac-406d-9f84-4bf07dddc81f]    [Dublin]
# 159                                      []          []
# 160                                      []          []
# 161  [8921b28b-b4ac-406d-9f84-4bf07dddc81f]    [Dublin]
# 162  [8921b28b-b4ac-406d-9f84-4bf07dddc81f]    [Dublin]
# ..                                      ...         ...
# 468                                      []          []
# 469                                      []          []
# 470                                      []          []
# 471                                      []          []
# 472                                      []          []
#
# [144 rows x 7 columns]

# %%
records_df.shape
# Out:
# (144, 7)

# %%
spese_df = records_df[records_df['category_id'].isin(SPESE['categories'].keys()) &
           (records_df['amount'] < 0)]
spese_amount = round(spese_df.amount.sum(), 2)

# %%
income_df = records_df[records_df['category_id'].isin(INCOME['categories'].keys()) &
           (records_df['amount'] > 0)]
income_amount = round(income_df.amount.sum(), 2)

# %%
rimborsi_df = records_df[records_df['category_id'].isin(RIMBORSI['categories'].keys()) &
           (records_df['amount'] > 0)]
rimborsi_amount = round(rimborsi_df.amount.sum(), 2)

# %%
investimenti_df = records_df[records_df['category_id'].isin(INVESTIMENTI['categories'].keys()) &
           (records_df['amount'] > 0)]
investimenti_amount = round(investimenti_df.amount.sum(), 2)

# %%
buoni_pasto_df = records_df[records_df['category_id'].isin(BUONI_PASTO['categories'].keys()) &
           (records_df['amount'] > 0)]
buoni_pasto_amount = round(buoni_pasto_df.amount.sum(), 2)

# %%
cash_flow = round(income_amount + rimborsi_amount + spese_amount, 2)
print(f"Spese: {spese_amount}€")
print(f"Income: {income_amount}€")
print(f"Rimborsi: {rimborsi_amount}€")
print("\n")
print(f"Buoni pasto: {buoni_pasto_amount}€")
print(f"Cash flow: {cash_flow}€")
print(f"Investimenti: {investimenti_amount}€")
# Out:
# Spese: -2764.17€
# Income: 2072.6€
# Rimborsi: 464.51€
#
#
# Buoni pasto: 0.0€
# Cash flow: -227.06€
# Investimenti: 4.26€

# %% [markdown]
# Categories non mappate

# %%
records_df[records_df['category_id'].isin([
    'ea566b98-446f-40eb-8071-f5289acf6716',
    #  'dcd71755-22e5-4f87-baa7-b07ad5cbbcb8',
     'd259f3dc-0630-4845-ad3b-af4facc22e0d',
     'a6daf078-746f-4de8-8d53-ddeab5abfe83',
    #  '0285055c-755c-4008-a5ef-84a8f2e77f0b',
    #  '68b6ced6-1c86-4534-8c88-704e0de6519e', # Tempo libero
     'dcd71755-22e5-4f87-baa7-b07ad5cbbcb8'
     ]
                                          )].sort_values('date')
# Out:
# Empty DataFrame
# Columns: [account, amount, date, category_id, category_name, label_ids, label_names]
# Index: []

# %% [markdown]
# ### Categories

# %%
categories = call_wallet_api("v1/api/categories")

# %%
categories
# Out:
# {'categories': [{'id': '025dcc04-511a-48a7-9d54-9c8330ec7fb3',
#    'color': '#64DD17',
#    'name': 'Bellezza & Benessere',
#    'createdAt': '2019-12-23T14:06:57Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '0285055c-755c-4008-a5ef-84a8f2e77f0b',
#    'color': '#cccccc',
#    'name': '',
#    'createdAt': '2020-03-04T10:27:18Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customName': False},
#   {'id': '03e0aa81-0318-46b0-9b63-91d7420e7ef6',
#    'color': '#AB47BC',
#    'name': 'Pedaggio',
#    'createdAt': '2021-05-20T20:32:53Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': True,
#    'customName': True,
#    'iconName': 'car-filled'},
#   {'id': '043f8b6a-60de-4ec7-bfb7-4c808f738c66',
#    'color': '#4fC3F7',
#    'name': 'Abbigliamento & Scarpe',
#    'createdAt': '2019-12-22T14:16:58Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '05a4d998-706f-4167-a964-f15a7a4a2767',
#    'color': '#cccccc',
#    'name': 'Automatic bank statements reading',
#    'createdAt': '2024-04-09T07:36:07Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customName': False},
#   {'id': '06b45615-a7d0-4f00-8992-95d6f9907c55',
#    'color': '#FF3D00',
#    'name': 'Spesa',
#    'createdAt': '2019-12-23T14:14:48Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '0e0ae827-900d-466b-b91c-b5af11f6d5c8',
#    'color': '#34BFF6',
#    'name': 'Drugstore',
#    'createdAt': '2021-06-07T22:07:36Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'enabled': True},
#   {'id': '11ad0c36-f9cc-4ed7-b82c-601780c46491',
#    'color': '#64DD17',
#    'name': 'TV & Streaming',
#    'createdAt': '2020-02-05T23:58:08Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '19bff33c-875e-4ce7-bf16-64ff29ebf59c',
#    'color': '#AA00FF',
#    'name': 'Veicoli',
#    'createdAt': '2019-12-23T13:58:21Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '1c796611-0d25-4611-b143-a827f02e309f',
#    'color': '#AA00FF',
#    'name': 'Manutenzione veicoli',
#    'createdAt': '2019-12-22T14:15:59Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '1fe10154-42a3-42b4-8ec1-b88980ce0346',
#    'color': '#FF4081',
#    'name': 'Risparmi',
#    'createdAt': '2019-12-22T12:02:06Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '202089f9-0aa1-4959-9dd9-7e905a2a99a6',
#    'color': '#64DD17',
#    'name': "Lotterie & Gioco d'azzardo",
#    'createdAt': '2019-12-22T20:25:35Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '22abfec7-d7b9-402b-896a-2242142b75fe',
#    'color': '#536DFE',
#    'name': 'Internet',
#    'createdAt': '2022-07-30T10:30:49Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '2409b680-1dfb-4926-99c8-652a92dc5a6a',
#    'color': '#64DD17',
#    'name': 'Culture, sport events',
#    'createdAt': '2020-08-08T16:26:50Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '26426aa6-55ef-43e2-afef-a0285fd5a424',
#    'color': '#4BB5C1',
#    'name': 'Fuel',
#    'createdAt': '2020-01-06T14:55:25Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'enabled': True},
#   {'id': '2979979c-6fa4-44f2-8a45-958749697ad0',
#    'color': '#34BFF6',
#    'name': 'Health & beauty',
#    'createdAt': '2021-06-07T22:07:36Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'enabled': True},
#   {'id': '3179b457-1ad6-4b0a-ae54-005ac04f6055',
#    'color': '#00BFA5',
#    'name': 'Taxes',
#    'createdAt': '2021-04-26T16:31:23Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '32818c0a-5472-4ddf-905c-66ee1f68dee0',
#    'color': '#4fC3F7',
#    'name': 'Jewels, accessories',
#    'createdAt': '2021-05-04T08:22:26Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '35794129-8e21-43bb-aba3-e09b53ec53f6',
#    'color': '#9E9E9E',
#    'name': 'Altro',
#    'createdAt': '2019-12-22T14:15:32Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '36d3a3a7-6395-49f8-b23f-fa2ddd5edc11',
#    'color': '#78909C',
#    'name': 'Trasporti',
#    'createdAt': '2019-12-20T19:32:24Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '37813c1a-6909-4678-9e56-680ee1bdc9ca',
#    'color': '#AA00FF',
#    'name': 'Rentals',
#    'createdAt': '2022-08-03T10:30:16Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '3c7ca941-8ddd-41a4-9fab-59af825f8dff',
#    'color': '#9E9E9E',
#    'name': 'Smarrimento',
#    'createdAt': '2019-12-22T11:51:32Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'cardinality': 'want',
#    'customCategory': False,
#    'customColor': False,
#    'customName': True},
#   {'id': '43602ea1-d211-4ec2-99d4-76cc838030a1',
#    'color': '#FF4081',
#    'name': 'Financial investments',
#    'createdAt': '2020-11-14T10:23:28Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '441f7a25-7962-423e-805c-4c5292036d55',
#    'color': '#536DFE',
#    'name': 'Telefono',
#    'createdAt': '2019-12-23T14:05:58Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '4a2f0581-b7b2-49ea-8660-095b5d87491d',
#    'color': '#00BFA5',
#    'name': 'Commissioni',
#    'createdAt': '2020-02-07T18:14:14Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': True},
#   {'id': '4befadf2-27f2-42b1-bdba-0a911d7b831b',
#    'color': '#AA00FF',
#    'name': 'Parcheggio',
#    'createdAt': '2020-01-22T13:05:33Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '4fc4f54c-6f66-43df-ac7e-539fc69f05ff',
#    'color': '#FBC02D',
#    'name': 'Entrate',
#    'createdAt': '2019-12-22T16:20:05Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '51a9ed48-13bf-4a60-b9a1-efa78009f4de',
#    'color': '#64DD17',
#    'name': 'Alcohol, tobacco',
#    'createdAt': '2020-08-09T17:48:59Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '5383eb57-e517-487b-9358-57c1ba2b2e16',
#    'color': '#78909C',
#    'name': 'Taxi',
#    'createdAt': '2022-05-25T18:26:15Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': False,
#    'customName': False},
#   {'id': '58e7b0c4-56ac-4fe5-bf29-b94454688ab9',
#    'color': '#FFB300',
#    'name': 'Paghetta',
#    'createdAt': '2020-12-22T14:38:26Z',
#    'updatedAt': '2026-02-23T08:07:44Z',
#    'customCategory': False,
#    'customColor': True,
#    'customName': True,
#    'iconName': 'billing-filled'}],
#  'limit': 30,
#  'nextOffset': 30,
#  'offset': 0}

# %%
categories_df = pd.DataFrame()

i = 0
while True:
    n_cat_retrieved = i * 100
    args = {
        "limit": 100,
        "offset": n_cat_retrieved
    }
    cat_page = call_wallet_api("v1/api/categories", args=args)
    
    if not cat_page['categories']:  # Stop when no more items are returned
        break
    
    for cat in cat_page['categories']:
        id = cat['id']
        name = cat['name']
        categories_df = pd.concat([categories_df, pd.DataFrame([{"id": id, "name": name}])], ignore_index=True)
    
    i += 1

# %%
for i, row in categories_df.iterrows():
    print(row['name'], row['id'])
# Out:
# Bellezza & Benessere 025dcc04-511a-48a7-9d54-9c8330ec7fb3
#  0285055c-755c-4008-a5ef-84a8f2e77f0b
# Pedaggio 03e0aa81-0318-46b0-9b63-91d7420e7ef6
# Abbigliamento & Scarpe 043f8b6a-60de-4ec7-bfb7-4c808f738c66
# Automatic bank statements reading 05a4d998-706f-4167-a964-f15a7a4a2767
# Spesa 06b45615-a7d0-4f00-8992-95d6f9907c55
# Drugstore 0e0ae827-900d-466b-b91c-b5af11f6d5c8
# TV & Streaming 11ad0c36-f9cc-4ed7-b82c-601780c46491
# Veicoli 19bff33c-875e-4ce7-bf16-64ff29ebf59c
# Manutenzione veicoli 1c796611-0d25-4611-b143-a827f02e309f
# Risparmi 1fe10154-42a3-42b4-8ec1-b88980ce0346
# Lotterie & Gioco d'azzardo 202089f9-0aa1-4959-9dd9-7e905a2a99a6
# Internet 22abfec7-d7b9-402b-896a-2242142b75fe
# Culture, sport events 2409b680-1dfb-4926-99c8-652a92dc5a6a
# Fuel 26426aa6-55ef-43e2-afef-a0285fd5a424
# Health & beauty 2979979c-6fa4-44f2-8a45-958749697ad0
# Taxes 3179b457-1ad6-4b0a-ae54-005ac04f6055
# Jewels, accessories 32818c0a-5472-4ddf-905c-66ee1f68dee0
# Altro 35794129-8e21-43bb-aba3-e09b53ec53f6
# Trasporti 36d3a3a7-6395-49f8-b23f-fa2ddd5edc11
# Rentals 37813c1a-6909-4678-9e56-680ee1bdc9ca
# Smarrimento 3c7ca941-8ddd-41a4-9fab-59af825f8dff
# Financial investments 43602ea1-d211-4ec2-99d4-76cc838030a1
# Telefono 441f7a25-7962-423e-805c-4c5292036d55
# Commissioni 4a2f0581-b7b2-49ea-8660-095b5d87491d
# Parcheggio 4befadf2-27f2-42b1-bdba-0a911d7b831b
# Entrate 4fc4f54c-6f66-43df-ac7e-539fc69f05ff
# Alcohol, tobacco 51a9ed48-13bf-4a60-b9a1-efa78009f4de
# Taxi 5383eb57-e517-487b-9358-57c1ba2b2e16
# Paghetta 58e7b0c4-56ac-4fe5-bf29-b94454688ab9
# Ripetizioni 61afe20f-fe65-4efa-aefb-4b41eb10a92e
# Manutenzione 62035cd4-838f-418c-a0d9-98e0931bfbb5
# Holiday, trips, hotels 66f877b4-30ca-4920-b78e-14cc36a68e9b
#  68b6ced6-1c86-4534-8c88-704e0de6519e
# Casa 6d2271c1-ff89-4552-9da3-196626aac7c4
# Prestiti & Interessi 718c18df-f85d-488f-be11-0e44bebc526b
# Interessi 7af26741-a212-47da-a50c-baeb717e9db4
# Animali domestici 7b1ab11c-bee3-4460-9a65-791b77510014
# Eventi 7c7dfaee-3be0-474e-b337-bd8b4e735940
# Services 835e838a-8ce0-4b9f-8ca3-9e628bc77348
# Premi 892593d3-451c-45e5-8518-9c233abd38db
# Home, garden 8a55709c-b88b-443f-9395-be0e0579edfa
# Interest, dividends 8b6a6c2a-f08a-44f5-bc12-60c8ccd268df
# Fines 8f78088b-8d9e-4c76-92b4-9748eff28b9f
# Bonus 91a849fe-db27-4455-beaf-15e9ddf2deb9
# Sconosciuto 926cc8c8-3482-4630-9032-83c6c348fa1a
# Rimborsi calcio 93117202-313b-4c3d-8cb7-45e284024516
# Unknown Income 93d63206-47e9-457f-a59e-d54b44478225
# Sport & Fitness 94ec9c3f-391d-4395-bb93-f2e1924d3e64
# Lotterie & Gioco d'azzardo 979f1b8b-5412-40d9-9e06-a869f5f27ef5
# Rete telefonica fissa 9896e24f-9875-4b94-8dc6-f968c3b5e84c
# Assicurazione immobili 9af92dfc-1dfa-4d83-80b3-ad2447970be2
# Vendite 9d2eb0c2-f0a3-48ac-b9ab-ed11d95e3b3d
# Bar & Locali 9defe17c-1cd4-4460-8ece-96fd90a76690
# Dividends a04096d4-7436-47dd-b6a0-5f545e7eff20
# Shopping a0e0eaa6-9f83-43fd-afd7-59e20d0381ae
# Regali a2cb741c-753d-40e6-bcf4-cc4acc7b36d5
# Life & Entertainment a45fe304-d61c-486e-98b8-7e2f90e0c8ae
# Buoni pasto a5cdc9ef-d31f-4c16-8840-421165b76037
#  a6daf078-746f-4de8-8d53-ddeab5abfe83
# Refund abe4d82d-ea09-43d4-a5e7-e27217842bf3
# Long distance ae0f2975-9b72-4cbb-a810-a1092d7e673e
# Formazione & Sviluppo b00d0301-b0de-4a08-b3c9-d6a3c68dda02
# Spese finanziarie b3cf77b0-3dfb-4182-a82e-43d307287baa
# Vehicle insurance b480c589-a9bd-4d61-bf3f-0551faff8838
# Trasferimento, Prelievo b6a83884-8a6b-4071-a660-e1a36bc28cde
# Trasporto pubblico bbd7c12b-8482-4154-83ec-66ae33d1ad9e
# Postal services bde7d02a-5ef8-4702-9883-4ab23aace98f
# Prestiti & Noleggi bf461213-9334-4189-9960-744b2f9b827f
# Rimborsi c196e895-83d8-4118-b744-94321501287e
# Realty c1c19810-a76b-448c-be98-807361998bc4
# Stipendio c232f841-d12b-491a-b659-8e8e747a0454
# Rent c2d55850-4582-421b-accf-c5db2d8e3d57
# Business trips c8d2dda6-ca86-4ee4-adeb-9c531f4e4d93
# Cancelleria & Utensili caa676db-ae3d-4456-8563-21c3506d309c
# Salute cb9d72f3-2b31-4dfe-ab4a-feafe8bdf3de
# Software, apps, games cd302b21-35ff-407a-ad29-965f33dbab09
#  d259f3dc-0630-4845-ad3b-af4facc22e0d
# Interests and Dividends d3cffaf0-b543-4550-b3c8-1780fdfbf76f
# Regali d69edfb5-81ef-42b5-8908-49db1a17e9a6
# Investments d922ce7f-9379-4078-811a-3b5b502f0e58
# Cibo & Bevande da124eef-0630-48ca-9af6-67c36b96740c
# Leti da3fcf77-52a4-41ca-bba3-bd06493ba159
# Energia & Utenze dc9a2f8e-c233-4027-a612-4913a406ff3f
#  dcd71755-22e5-4f87-baa7-b07ad5cbbcb8
# Unknown Expense e3504ae6-2463-4c18-94e3-7b556f39d534
# Charity, gifts e67d57f4-5a62-4f0b-a465-86e001c62e63
#  ea566b98-446f-40eb-8071-f5289acf6716
# Hobbies f42ffe7e-7710-491c-abf3-fc7b92cef42a
# Books, audio, subscriptions fb90fae9-b395-4e48-9574-aff68dd2d560
# Ristoranti & Fast-food fe2cd110-9275-4f28-92f0-ecb3bfb1663e

# %% [markdown]
# # Filters
